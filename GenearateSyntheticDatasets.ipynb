# %% [markdown]
# # Generate synthetic data

# %% [markdown]
# for each robustness test we do, we will need different synthetic data. In this notebook I generate all of the synthetic datasets so they can be kept organised

# %%
output_dir = "./massive_data/"

# %%
from utils.dependencies import *
asp_import("synthetic_ms_candidates", "sd")
# Out:
# <module 'synthetic_ms_candidates' from '/home/bepennell/research/AstrometricSignalProcessing/SyntheticDatasets/synthetic_ms_candidates.py'>

# %%
mdwarfs = Table.read('./massive_data/2026_05_19_final_cut_table.fits', format='fits')
reduced_mdwarfs = mdwarfs[["ra", "dec", "pmra", "pmdec", "parallax", "phot_g_mean_mag", "bp_rp", "mass_single", "mh_single", "q_max"]]

# %% [markdown]
# Open up the dataset and create a lower-memory version of the catalogue with only the relevant entries

# %%
def generate_dataset(name, catalogue, object_count=250000, binary_fraction=0.3, binarity_model=None, period_model=(4,1.3), p_lim=(1,8), mass_model=0, ecc_type="turnover", save=True, return_fits=False):
    outdata = dict()
    outdata["meta"] = dict()
    outdata["meta"]["timestamp"] = datetime.now()
    outdata["meta"]["object_count"] = object_count
    outdata["meta"]["binary_fraction"] = binary_fraction
    outdata["meta"]["binarity_model"] = f"{binarity_model}"
    outdata["meta"]["period_model"] = period_model
    outdata["meta"]["mass_model"] = mass_model
    outdata["meta"]["ecc_type"] = ecc_type
    outdata["data"] = sd.create_synthetic_data(object_count=object_count, catalogue=catalogue, binary_fraction=binary_fraction, binarity_model=binarity_model,
                                               period_model=period_model, p_lim=p_lim, mass_model=mass_model, ecc_type=ecc_type, return_ruwe=True, return_fits=return_fits)

    if not save:
        return outdata

    outfile = open(output_dir+f'{date.today()}-{name}.pkl', "wb")
    pickle.dump(outdata, outfile)
    outfile.close()

# %% [markdown]
# ## Step 1: the reference dataset

# %% [markdown]
# The main dataset to make will be one of "conventional wisdom", and all other datasets will just be slight modifications to this one

# %%
generate_dataset(name="reference", catalogue=reduced_mdwarfs, object_count=len(mdwarfs)) # this one has all the presets.
# Out:
# ...
# Computing Binaries:   0%|          | 0/75070 [00:00<?, ?it/s]

# %% [markdown]
# ## Variable binary fraction

# %%
REF_FRACTIONS = (0.25, 0.5)
MASS_RANGE = (0.2, 0.45)
def bin_frac(m):
    sep = (m - MASS_RANGE[0]) / (MASS_RANGE[1] - MASS_RANGE[0])
    return sep * (REF_FRACTIONS[1] - REF_FRACTIONS[0]) + REF_FRACTIONS[0]
generate_dataset(name="mod_variable_binarity", catalogue=reduced_mdwarfs, object_count=len(mdwarfs), binary_fraction=None, binarity_model=bin_frac)
# Out:
# ...
# Computing Binaries:   0%|          | 0/99138 [00:00<?, ?it/s]

# %% [markdown]
# ## Period test

# %%
generate_dataset(name="periods_42", catalogue=reduced_mdwarfs, object_count=50000, period_model=(4,2))
generate_dataset(name="periods_513", catalogue=reduced_mdwarfs, object_count=50000, period_model=(5,1.3))
# Out:
# ...
# Computing Binaries:   0%|          | 0/15022 [00:00<?, ?it/s]

# %% [markdown]
# ## Mass ratio test

# %%
generate_dataset(name="flat_q", catalogue=reduced_mdwarfs, object_count=50000, mass_model=0.5)
generate_dataset(name="gamma1", catalogue=reduced_mdwarfs, object_count=50000, mass_model=1)
# Out:
# ...
# Computing Binaries:   0%|          | 0/15170 [00:00<?, ?it/s]

# %% [markdown]
# ## Eccentricity test

# %%
generate_dataset(name="circular", catalogue=reduced_mdwarfs, object_count=50000, ecc_type="circular")
generate_dataset(name="thermal", catalogue=reduced_mdwarfs, object_count=50000, ecc_type="thermal")
# Out:
# ...
# Computing Binaries:   0%|          | 0/15016 [00:00<?, ?it/s]
